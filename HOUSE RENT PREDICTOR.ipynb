# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore", category=UserWarning)                                 # User warning handling

# %%
df = pd.read_excel("D:\\SPREADSHEETS\\HouseRent.xlsx", "Sheet1")                        # DataFrame

# %%
df.head()
# Out:
#    Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0 2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1 2022-05-13    2  20000   800       1 out of 3   Super Area
# 2 2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3 2022-07-04    2  10000   800       1 out of 2   Super Area
# 4 2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
df.tail()
# Out:
#       Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741 2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner

# %%
plt.scatter(df['Size'], df["Rent"])
plt.xlabel('Size')
plt.ylabel('Rent')
# Out:
# Text(0, 0.5, 'Rent')

# %%
x = df[['BHK', 'Size', 'Bathroom']]                                                     # Features and Target
y = df['Rent']

# %%
reg = linear_model.LinearRegression()
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
# Welcome Message
print("\t\t\tWELCOME\n\t\tHOUSE RENT PREDICTOR")

# Specifications
while True:
    # User Inputs
    print("\nEnter these specifications")
    bhk = int(input("BHK: "))
    print("BHK: ",bhk)
    size = float(input("Size (in sq feet): "))
    print("Size (in sq feet): ",size)
    bth = int(input("Number of bathrooms: "))
    print("Number of bathrooms: ", bth)

    rent = reg.predict([[bhk, size, bth]])                                              # Prediction
    print("House rent as per the specifications: ", "{:.2f}".format(rent[0]))

    # Continue or Exit
    c = input("Enter 'y' to predict again, 'n' to exit the program: ")
    if c in ['y', 'Y', 'Yes', 'YES', 'yes']:
        continue
    elif c in ['n', 'N', 'No', 'NO', 'no']:
        break

# Closing Message
print("\t\tPREDICTOR CLOSED")
# Out:
# 			WELCOME
# 		HOUSE RENT PREDICTOR
#
# Enter these specifications
# BHK:  4
# Size (in sq feet):  65465
# Number of bathrooms:  4
# House rent as per the specifications:  1650924.93
# Enter 'y' to predict again, 'n' to exit the program:  y
# Enter these specifications
# BHK:  9
# Size (in sq feet):  546624
# Number of bathrooms:  10
# House rent as per the specifications:  13470385.34
# Enter 'y' to predict again, 'n' to exit the program:  n
# 		PREDICTOR CLOSED
